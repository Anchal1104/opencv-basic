# %%
print("Hello")
# Out:
# Hello

# %%
import numpy as np
a=np.array([1,2,3,4,5])
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
#plotting
import cv2
from matplotlib import pyplot as plt
img1 = cv2.imread(r"C:\Users\welcome\OneDrive\Desktop\age gender detector\data\pic.png.jpg")
plt.imshow(img1)

# %%
#Arithemtic operations
img1 = cv2.imread(r"C:\Users\welcome\OneDrive\Desktop\age gender detector\data\pic.png.jpg")
img2 = cv2.imread(r"C:\Users\welcome\OneDrive\Desktop\age gender detector\data\pic2.jpg")
result= img1+img2           #Addition
plt.imshow(result)

# %%
result = img1-img2          #Subtraction
plt.imshow(result)

# %%
result= img1*img2       #multiplication
plt.imshow(result)

# %%
result = img1/img2       #division
plt.imshow(result)
# Out:
# C:\Users\welcome\AppData\Local\Temp\ipykernel_19408\348188838.py:1: RuntimeWarning: divide by zero encountered in divide
#   result = img1/img2
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
pic=cv2.imread(r"C:\Users\welcome\OneDrive\Desktop\age gender detector\data\friend.jpg")
img=cv2.cvtColor(pic,cv2.COLOR_BGR2HSV)
figure_size=7
result=cv2.blur(img,(figure_size,figure_size))
plt.figure(figsize=(11,6))
plt.subplot(121),plt.imshow(cv2.cvtColor(img,cv2.COLOR_HSV2RGB)),plt.title("original")
plt.xticks([]),plt.yticks([])
plt.subplot(122),plt.imshow(cv2.cvtColor(result,cv2.COLOR_HSV2RGB)),plt.title("blurred")
plt.xticks([]),plt.yticks([])
plt.show()

# %%
img1 = cv2.imread(r"C:\Users\welcome\OneDrive\Desktop\age gender detector\data\pic.png.jpg")

# %%
(height,width)=img1.shape[0:2]
zoom=cv2.resize(img1,None,fx=1,fy=1.5,interpolation=cv2.INTER_CUBIC)
plt.imshow(zoom)

# %%
zoom=cv2.resize(img1,(int(width*2),int(height*2)),interpolation=cv2.INTER_CUBIC)
plt.imshow(zoom)

# %%
m=cv2.getRotationMatrix2D((width/2,height/2),30,1)
rotate=cv2.warpAffine(img1,m,(height,width))
plt.imshow(rotate)

# %%
import numpy as np
m=np.float32([[1,0,50],[0,1,100]])
dst=cv2.warpAffine(img,m,(height,width))
plt.imshow(dst)
